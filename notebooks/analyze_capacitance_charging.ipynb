# %%
from sys import path
path.append('./spineSimulator/')
import plot
from importlib import reload
reload(plot)
# Out:
# <module 'plot' from '/home/work/Projects/spineCableSimulation/code/./spineSimulator/plot.py'>

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Input only to first segment (along x)

# %%
# AMPA current intput to segments 1 in spine head
results_file_10ps = './../simulation_results/CapCharge_10psTimestep_1AMPAseg_11082022.pcl'
results_file_100ps = './../simulation_results/CapCharge_100psTimestep_1AMPAseg_11082022.pcl'
results_10ps = pickle.load(open(results_file_10ps, 'rb'))
results_100ps = pickle.load(open(results_file_100ps, 'rb'))

# %%
#%matplotlib notebook
reload(plot)

results = results_10ps
t = list(results['data'].keys())
phi = np.array([results['data'][ti]['phi'] for ti in t])
c_Na = np.array([results['data'][ti]['c_Na'] for ti in t])
c_K = np.array([results['data'][ti]['c_K'] for ti in t])
c_Cl = np.array([results['data'][ti]['c_Cl'] for ti in t])
x = results['params']['x']
xx, tt = np.meshgrid(x,t)


fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, phi)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Na)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_K)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Cl)
plt.show()

# %%
#%matplotlib notebook
results = results_100ps
t = list(results['data'].keys())
phi = np.array([results['data'][ti]['phi'] for ti in t])
c_Na = np.array([results['data'][ti]['c_Na'] for ti in t])
c_K = np.array([results['data'][ti]['c_K'] for ti in t])
c_Cl = np.array([results['data'][ti]['c_Cl'] for ti in t])
x = results['params']['x']
xx, tt = np.meshgrid(x,t)

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, phi)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Na)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_K)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Cl)
plt.show()

# %% [markdown]
# ## Input to 3 out of 4 head segments

# %%
# AMPA current intput to segments 1,2,3 in spine head
results_file_10ps = './../simulation_results/CapCharge_10psTimestep_11082022.pcl'
results_file_100ps = './../simulation_results/CapCharge_100psTimestep_11082022.pcl'
results_10ps = pickle.load(open(results_file_10ps, 'rb'))
results_100ps = pickle.load(open(results_file_100ps, 'rb'))

# %%
#%matplotlib notebook
reload(plot)

results = results_10ps
t = list(results['data'].keys())
phi = np.array([results['data'][ti]['phi'] for ti in t])
c_Na = np.array([results['data'][ti]['c_Na'] for ti in t])
c_K = np.array([results['data'][ti]['c_K'] for ti in t])
c_Cl = np.array([results['data'][ti]['c_Cl'] for ti in t])
x = results['params']['x']
xx, tt = np.meshgrid(x,t)


fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, phi)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Na)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_K)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Cl)
plt.show()

# %%
#%matplotlib notebook
reload(plot)

results = results_100ps
t = list(results['data'].keys())
phi = np.array([results['data'][ti]['phi'] for ti in t])
c_Na = np.array([results['data'][ti]['c_Na'] for ti in t])
c_K = np.array([results['data'][ti]['c_K'] for ti in t])
c_Cl = np.array([results['data'][ti]['c_Cl'] for ti in t])
x = results['params']['x']
xx, tt = np.meshgrid(x,t)


fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, phi)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Na)
plt.show()

reload(plot)
fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_K)
plt.show()

fig = plt.figure(dpi=200, figsize=(3,3))
pos = [0.1,0.1,0.8,0.8]
plot.surface(fig, pos, xx, tt, c_Cl)
plt.show()

# %% [markdown]
# # How strong can the head be depolarized for different paramters?
# # What is the current through the neck?
